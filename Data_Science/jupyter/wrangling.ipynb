# %%
import pandas as pd


df3 = pd.DataFrame({
    'key': [100,101],
    'name': ['ritesh','kapil']
})
df4 = pd.DataFrame({
    'key': [100,102],
    'name': ['ritesh','kapil']
})
t3.merge(t4)

# %%
df3 = pd.DataFrame({
    'group': ['accounting','hr','it','marketing'],
    'supervisor': ['abc','def','ghi','rohit']
})

df4 = pd.DataFrame({
    'group': ['accounting','hr','it','marketing'],
    'supervisor': ['ritesh','kapil','rohit','rohit']
})
display(df3,df4)

merged_df = pd.merge(df3,df4,on='group')
display(merged_df)


'''many to many join'''
df5 = pd.DataFrame({
    'group': ['accounting', 'accounting', 'engineering', 'engineering', 'hr', 'hr'],
    'skills': ['math', 'spreadsheets', 'software', 'math', 'spreadsheets', 'psychology']
})
df6 = pd.DataFrame({
    'group': ['accounting', 'engineering', 'engineering', 'hr', 'hr'],
    'supervisor': ['Carly', 'Guido', 'Steve', 'Dale', 'Andy']
})
display(pd.merge(df5, df6))
