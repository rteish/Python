# %%
import json

# %%
with open('student_details.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# {'student': {'name': 'John Doe', 'roll_number': '2024001', 'section': 'A', 'department': 'Computer Science', 'gender': 'Male', 'phone_number': '+977-9841234567', 'email_id': 'john.doe@example.com', 'semester': '5th', 'year': '2024', 'address': {'city': 'Kathmandu', 'country': 'Nepal'}, 'subjects': ['Data Structures', 'Database Management', 'Web Development', 'Algorithms'], 'cgpa': 3.75}}

# %%
import pandas as pd 

df = pd.read_json('student_details.json')
df.head()

df.loc['percentage'] = (df.loc['cgpa'] * 100)
df.to_json('student_details.json', orient='records', lines=True)

# %%
import student
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import excel
#
# ModuleNotFoundError: No module named 'excel'

# %%
import pandas as pd

df = pd.read_csv('sudent.xlsx')
df.head()
# Out:
#      name  roll_number section        department gender  phone_number  \
# 0  ritesh      2024001       A  Computer Science   Male    9841234567
# 1   kapil      2024002       A  Computer Science   Male    9841234567
#
#                email_id semester  year  address  subjects  cgpa
# 0  john.doe@example.com      5th  2024      NaN       NaN   NaN
# 1  john.doe@example.com      5th  2024      NaN       NaN   NaN
